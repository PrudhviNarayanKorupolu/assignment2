# %% [markdown]
# <a href="https://colab.research.google.com/github/PrudhviNarayanKorupolu/assignment2/blob/main/INFO5731_Assignment_Two.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **INFO5731 Assignment Two**
#
# In this assignment, you will try to gather text data from open data source newfileia web scraping or API. After that you need to clean the text data and syntactic analysis of the data.

# %% [markdown]
# # **Question 1**

# %% [markdown]
# (20 points). Write a python program to collect text data from **either of the following sources** and sanewfilee the data into a **csnewfile file**:
#
# (1) Collect all the customer renewfileiews of the product [Apple iPhone 11](https://www.amazon.com/Apple-iPhone-11-64GB-Unlocked/dp/B07ZPKF8RG/ref=sr_1_13?dchild=1&keywordd=iphone+12&qid=1631721363&sr=8-13) on amazon.
#
# (2) Collect all User Renewfileiews of the film [Shang-Chi and the Legend of the Ten Rings](https://www.imdb.com/title/tt9376612/renewfileiews?ref_=tt_sa_3) from IMDB.
#
# (3) Collect all the abstracts research papers by using the query [smart health](https://citeseerx.ist.psu.edu/search?q=natural+language+processing&submit.x=0&submit.y=0&sort=rlnewfile&t=doc) from CiteSeerX.
#
# (4) Collect the top 10,000 tweets by using hashpos_tag_sents ["#blacklinewfileesmatter"](https://twitter.com/hashpos_tag_sents/blacklinewfileesmatter) from Twitter with the following requirements: Location (Texas), Time frame (2021-01-01 to 2021-09-01).

# %%
import requests
from bs4 import BeautifulSoup
import re
import pandas as pd
import numpy as np
import itertools
import lxml.html as LH
url = 'https://www.imdb.com/title/tt9376612/reviews?ref_=tt_sa_3'
imdb_url = "https://www.imdb.com"
response = requests.get(url)
soups = BeautifulSoup(response.text, 'lxml')
tagss = soups.find_all('a', attrs={'class': None})
tagss = [tag.attrs['href'] for tag in tagss 
              if tag.attrs['href'].startswith('/title') & tag.attrs['href'].endswith('/')]
tagss = list(dict.fromkeys(tagss))
linkss = [imdb_url + tag + 'reviews' for tag in tagss]
def minMax(a):
      print(len(a))
      minp = a.index(min(a))
      maxpos = a.index(max(a))
      return minp, maxpos
def getReviews(soup):
    review_ratings = [tag.previous_element for tag in 
                           soup.find_all('span', attrs={'class': 'point-scale'})]
    if len(review_ratings) > 0:
      n_index, p_index = minMax(list(map(int, review_ratings)))
      review_list = soup.find_all('a', attrs={'class':'title'})
      reviews = ["https://www.imdb.com" + review['href'] for review in review_list]
      return reviews
    else:
      return None
def soupsgwt(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    return soup
def reviwe(review_url):
    soup = soupsgwt(review_url)
    tag = soup.find('div', attrs={'class': 'text show-more__control'})
    return tag.getText()
def namwe(review_url):    
    soup = soupsgwt(review_url)
    tag = soup.find('h3')
    return list(tag.children)[0].getText()
def titlew(review_url):    
    soup = soupsgwt(review_url)
    tag = soup.find('h1')
    return list(tag.children)[1].getText()
def posrtrt(review_url):    
    soup = soupsgwt(review_url)
    tag = soup.find('div', attrs={'class': 'display-name-date'})
    return list(tag.children)[1].getText()
def rats(review_url):    
    soup = soupsgwt(review_url)
    tag = soup.find('div', attrs={'class': 'ipl-ratings-bar'})
    return list(tag.children)[1].getText()
movewee = soupsgwt(linkss[0])
reviewew = getReviews(movewee)
tests = [reviwe(url) for url in reviewew]
names = [namwe(url) for url in reviewew]
ratings = [rats(url) for url in reviewew]
postedates = [posrtrt(url) for url in reviewew]
data = {'User_Name': names,
        'Review_text': tests,
        'Review_posted_time': postedates,
        'Star': ratings}
df = pd.DataFrame(data)
df.head(25)
# Out:
# 25
#                            User_Name  ...                 Star
# 0                  dominicwood-14504  ...   \n\n\n\n\n\n9/10\n
# 1                      laviniadallam  ...  \n\n\n\n\n\n10/10\n
# 2   Radio-1s_Mr-MovieMad-Ami_104-1FM  ...   \n\n\n\n\n\n9/10\n
# 3                       mhatreritesh  ...   \n\n\n\n\n\n9/10\n
# 4                  nishantsalhotrans  ...  \n\n\n\n\n\n10/10\n
# 5                 truthtellers-16825  ...   \n\n\n\n\n\n8/10\n
# 6                            csheff3  ...   \n\n\n\n\n\n9/10\n
# 7                      IliescuVictor  ...   \n\n\n\n\n\n9/10\n
# 8                           handaloo  ...   \n\n\n\n\n\n7/10\n
# 9                         JATIN-1989  ...   \n\n\n\n\n\n4/10\n
# 10                          MrSAsheC  ...   \n\n\n\n\n\n5/10\n
# 11                           delsoca  ...   \n\n\n\n\n\n7/10\n
# 12                         wgeddings  ...   \n\n\n\n\n\n9/10\n
# 13                  MiroslavKyuranov  ...   \n\n\n\n\n\n8/10\n
# ...

# %% [markdown]
# # **Question 3**

# %% [markdown]
# # **Question 2**

# %% [markdown]
# (30 points) Here is a [legal case](https://github.com/unt-iialab/info5731-fall2021/blob/main/assignments/01-05-1%20%20Adams%20newfile%20Tanner.txt) we collected from westlaw, please follow the steps we mentioned in lesson 5 to clean the data:
#
#
#
# (1) Basic feature extraction using text data
#
# *   Number of sentences
# *   Number of wordd
# *   Number of characters
# *   Anewfileerage word length
# *   Number of stopwordd
# *   Number of special characters
# *   Number of numerics
# *   Number of uppercase wordd
#
# (2) Basic Text Pre-processing of text data
#
# *   Lower casing
# *   Punctuation remonewfileal
# *   Stopwordd remonewfileal
# *   Frequent wordd remonewfileal
# *   Rare wordd remonewfileal
# *   Spelling correction
# *   tokenize Stemming
# *   Lemmatization
#
# (3) Sanewfilee all the **clean sentences** to a **csnewfile file** (one column, each raw is a sentence) after finishing all the steps abonewfilee.
#
#
# (4) Adnewfileance Text Processing
#
# *   Calculate the term frequency of all the terms.
# *   Print out top 10 1-gram, top 10 2-grams, and top 10 3-grams terms as features.

# %%
#Number of sentences
from google.colab import files
upload = files.upload()

file = "mam.txt"
upload[file].decode("utf-8")

upload[file].decode("utf-8").split("\r\n")

data = upload[file].decode("utf-8").split("\r\n")

for i in range(len(data)):
  data[i] = data[i].split(",")

print(data)
# Out:
#      <input type="file" id="files-e00cc775-3269-45ba-887b-ce01af743649" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e00cc775-3269-45ba-887b-ce01af743649">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving mam.txt to mam (2).txt
# ...

# %%
#Number of wordd
#Number of characters
#Anewfileerage word length

file = open("mam.txt", "r")

sentences = 0
wordd = 0
characters = 0
new1=0
new2
for line in file:
  line = line.strip("\n")
  sentence = line.count(".")


  words = line.split()
  #sentences += line.count('.')
  sentences += 1
  wordd += len(words)
  characters += len(line)



file.close()

print("total number of Sentences:", sentences, "\n total number of Words:", wordd, "\n total number of Characters:", characters)
# Out:
# total number of Sentences: 158
#  total number of Words: 3707
#  total number of Characters: 20295

# %%
#avg word count

newfile=input('file name: ')
f=open(newfile,'r')
new1=0
new2=0
for line in f:
    new1+=1
    words=line.rstrip().split()
for word in words:
    new2+=1
avg=new1/new2
print('Average length: ',avg)
# Out:
# file name: mam.txt
# Average length:  19.75

# %%
#no.of stopwords
#no.of stopwords

import nltk
nltk.download('stopwords')
stop = stopwords.words('english')
print(stopwords.words('english'))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...

# %%
import re

digit=0
number = 0
nwe = []
#count=0

with open ("mam.txt") as f:
  for line in f.readlines():
    sub_strs = line.rstrip().split("-")
    for i in range(0, len(sub_strs)):
      filewords = re.split(r"[a-zA-Z\W]",sub_strs[i])
      for word in filewords:
        if word.isdigit():
          number += 1
          if i >=1 and sub_strs[i].startswith(word):
            nwe.append("-")
            nwe.append(word)
          else:
            nwe.append(word)


print("Numericals:",number)
print("numbers:",nwe)
# Out:
# Numericals: 156
# ...

# %%
def count(mam):                                               
    co = 0                                                                    
    with open(mam, 'r') as fp:                                              
        for line in fp:                                                          
            for w in filter(None, line.split()):                              
                if w[0].isupper():                                            
                    co += 1                                                   
    return co


print("total upper case:",count('mam.txt'))
# Out:
# total upper case: 462

# %%
with open('mam.txt', 'r') as fileinput:
   for l in fileinput:
       l = l.lower()
       print(l)
# Out:
# 5 ala. 740
#
# supreme court of alabama.
#
# adams
#
# v.
#
# tanner and horton.
#
# june term, 1843.
#
# synopsis
#
# writ of error to the circuit court of sumter.
#
#
#
#
#
#
#
# west headnotes (2)
#
#
#
#
#
# [1]
#
# chattel mortgages
#
# crops
#
# a growing crop has such an existence as to be the subject-matter of a mortgage or other contract which passes an interest to vest in possession, either immediately or at a future time.
#
# 4 cases that cite this headnote
#
#
#
# [2]
#
# creditors’ remedies
#
# lien and priority
#
# under st.1821, prohibiting a levy on a crop until it has been gathered, no lien attaches in favor of a fi. fa. on a growing crop, nor does such lien attach until after the crop has been gathered.
#
# 5 cases that cite this headnote
#
#
#
# ...

# %%
file = open('mam.txt', 'r')
t = file.read()

# initializing punctuations of the string

punc = '''!()-[]{};:,.'"?@#$%^&*'''

# Using loop along with punctuation string
for e in t:
    if e in punc:
        t = t.replace(e," ")
 
# result
print(text)
# Out:
# <function text at 0x7fc8b071ea70>

# %%
#stopwords
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Get nltk stopword list into a set.
sw = set(stopwords.words('english'))
 
# Open and read in a text file.
file = open("mam.txt")
line = file.read()
words = line.split()
 
# stopwords found counter.
found = 0
 
# If each word checked is not in stopwords list,
# then append word to a new text file.
for new in words:
    if not new.lower() in sw:
        # Not found on stopword list, so append.
        afile = open('stopwords-removed.txt','a')
        afile.write(" "+new)
        afile.close()
    else:
        # It's on the stopword list
        found +=1
        print(new)
 
print(found,"words found and removed")
print("Saved ")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# of
# AND
# of
# to
# the
# of
# A
# has
# such
# an
# as
# to
# be
# the
# of
# a
# or
# other
# which
# an
# to
# in
# or
# at
# a
# that
# this
# and
# Under
# a
# on
# a
# until
# it
# has
# been
# no
# in
# of
# a
# on
# a
# nor
# does
# such
# until
# after
# the
# has
# been
# that
# this
# This
# was
# a
# of
# the
# of
# under
# the
# In
# an
# from
# the
# of
# at
# the
# of
# the
# in
# the
# of
# that
# to
# of
# the
# of
# and
# the
# of
# and
# This
# was
# on
# of
# as
# the
# of
# which
# was
# and
# a
# to
# the
# An
# was
# up
# to
# the
# of
# the
# of
# the
# to
# the
# and
# to
# a
# On
# the
# a
# of
# was
# at
# the
# of
# the
# The
# that
# he
# his
# in
# that
# an
# was
# on
# the
# and
# that
# and
# up
# to
# the
# was
# that
# the
# on
# was
# on
# the
# of
# and
# by
# the
# in
# his
# It
# was
# by
# the
# by
# the
# of
# a
# that
# ...

# %%
#Remonewfileal of Frequent wordd

s = open('stopwords-removed.txt','r').read()  # Open the input file

# Program will count the characters in text file
new = len(s)

# Program will count the lines in the text file
new1 = s.count('\n')

# Program will call split with no arguments
wordd = s.split()
d = {}
for w in wordd:
    if w in d:
        d[w] += 1
    else:
        d[w] = 1

num_wordd = sum(d[w] for w in d)

list1 = [(d[w],w) for w in d]
list1.sort()
list1.reverse()

# downloaded an imported stopwordd from NLTK
from nltk.corpus import stopwords # Import the stop word list
from nltk.tokenize import wordpunct_tokenize

stop_wordd = set(stopwords.words('english')) #searching faster
print ([word for word in list1 if word not in stop_wordd])

i = 1
for count, word in list1[:10]:
    print('%2s. %4s %s' %(i,count,word))
    i+= 1
# Out:
# [(144, 'execution'), (116, 'crop'), (92, 'levy'), (88, 'v.'), (80, 'lien'), (68, 'right'), (60, 'crop,'), (60, 'Rep.'), (56, 'contract'), (56, 'Ala.'), (52, 'growing'), (52, 'claimants'), (48, 'defendant'), (44, '—'), (44, 'upon'), (44, 'Court'), (44, 'Case'), (40, 'time'), (40, 'law,'), (36, 'possession'), (36, 'gathered,'), (36, 'execution,'), (32, 'would'), (32, 'plaintiff'), (32, 'may'), (32, 'act'), (32, ','), (28, 'taken'), (28, 'subject'), (28, 'sale'), (28, 'property'), (28, 'made'), (28, 'levied'), (28, 'court'), (28, 'cotton'), (28, 'common'), (28, 'Term'), (28, 'Johns.'), (28, 'Cited'), (24, 'statute'), (24, 'sheriff'), (24, 'shall'), (24, 'planted'), (24, 'debtor,'), (24, 'could'), (24, 'case,'), (24, 'Tried'), (24, 'Hon.'), (24, 'Harrison,'), (24, 'Circuit'), (24, '5'), (20, 'without'), (20, 'whether'), (20, 'judgment'), (20, 'interest'), (20, 'give'), (20, 'fieri'), (20, 'claimants,'), (20, 'attached'), (20, 'APPEAL'), (20, 'A.'), (20, '2'), (20, '1840,'), (20, '&'), (1
# ...

# %%
#Rare wordd remonewfileal 

file = open('stopwords-removed.txt', 'r')
text = file.read()

text = text.lower()
wordd = text.split()
wordd = [word.strip('.,!;''()[]&') for word in wordd]
wordd = [word.replace("'s", '') for word in wordd]

#finding new
new = []
for word in wordd:
    if word not in new:
        new.append(word)

#new.sort()

print(new)
# Out:
# ['5', 'ala', '740', 'supreme', 'court', 'alabama', 'adams', 'v', 'tanner', 'horton', 'june', 'term', '1843', 'synopsis', 'writ', 'error', 'circuit', 'sumter', 'west', 'headnotes', '2', '1', 'chattel', 'mortgages', 'crops', 'growing', 'crop', 'existence', 'subject-matter', 'mortgage', 'contract', 'passes', 'interest', 'vest', 'possession', 'either', 'immediately', 'future', 'time', '4', 'cases', 'cite', 'headnote', 'creditors’', 'remedies', 'lien', 'priority', 'st.1821', 'prohibiting', 'levy', 'gathered', 'attaches', 'favor', 'fi', 'fa', 'attach', '**1', 'trial', 'right', 'property', 'statute', 'november', '1840', 'execution', 'issued', 'suit', 'plaintiff', 'requiring', 'sheriff', 'county', 'make', 'goods', 'c', 'allen', 'harrison', 'others', 'sum', 'thirty-seven', 'hundred', 'seventy-seven', '80-100', 'dollars', 'besides', 'costs', 'levied', 'thirty', 'bales', 'cotton', 'claimed', 'bond', 'given', 'try', 'issue', 'made', 'question', 'liability', 'plaintiff’s', 'submitted', 'jury', 'b
# ...

# %%
pip install textblob

# %%
#Spelling correction

from textblob import TextBlob

with open("stopwords-removed.txt", "r") as f:       
    text = f.read()
    # Making our first textblob
    textBlb = TextBlob(text)
    # Correcting the text   
    textCorrected = textBlb.correct()
    print(textCorrected)

# %%
#tokenize
import nltk
nltk.download('punkt')
obj = open('stopwords-removed.txt', 'r')
text = obj.read()
tokens = nltk.sent_tokenize(text)
print(tokens)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# ...

# %%
#Stemming
from nltk.stem import PorterStemmer
from nltk.tokenize import sent_tokenize, word_tokenize
#sentence="Hello Guru99, You hanewfilee to build a newfileery good site and I lonewfilee newfileisiting your site."
with open("stopwords-removed.txt", "r") as f:       
    text = f.read()
wordd = word_tokenize(text)
pro = PorterStemmer()
for w in wordd:
	rootWord=pro.stem(w)
	print(rootWord)
# Out:
# Streaming output truncated to the last 5000 lines.
# fieri
# facia
# ’
# ,
# issu
# regularli
# time
# levi
# made
# ;
# cotton
# levi
# grow
# plantat
# harrison
# ,
# cultiv
# hand
# servic
# .
# prove
# claimant
# ,
# product
# written
# contract
# ,
# harrison
# ,
# twenty-second
# may
# ,
# 1840
# ,
# consider
# claimant
# involv
# ,
# indors
# burton
# &
# harrison
# sumter
# counti
# ,
# expos
# execut
# ,
# amount
# upward
# fourteen
# thousand
# dollar
# ,
# bargain
# sold
# claimant
# grow
# crop
# cotton
# &
# c.
# ,
# consist
# one
# hundr
# twenti
# acr
# ,
# &
# c.
# allen
# harrison
# promis
# oblig
# give
# crop
# use
# claimant
# time
# save
# suffer
# indors
# ;
# crop
# matur
# gather
# undertook
# deliv
# cotton
# gainesvil
# .
# claimant
# came
# tennesse
# ,
# (
# where
# resid
# )
# first
# septemb
# ,
# 1840
# ,
# bring
# three
# four
# white
# labor
# ,
# took
# possess
# crop
# slave
# ,
# latter
# ,
# white
# labor
# ,
# gather
# cotton
# ,
# prepar
# ...

# %%
#Lemmatization
import nltk
nltk.download('wordnet')
from nltk.stem import 	WordNetLemmatizer
lemmer = WordNetLemmatizer()
#text = "studies studying cries cry"
with open("stopwords-removed.txt", "r") as f:       
    text = f.read()
tokenize = nltk.word_tokenize(text)
for w in tokenize:
 print("{} - {}".format(w, lemmer.lemmatize(w)))
# Out:
# Streaming output truncated to the last 5000 lines.
# fieri - fieri
# facias - facia
# ’ - ’
# , - ,
# issued - issued
# regularly - regularly
# time - time
# levy - levy
# made - made
# ; - ;
# cotton - cotton
# levied - levied
# growed - growed
# plantation - plantation
# Harrison - Harrison
# , - ,
# cultivated - cultivated
# hands - hand
# service - service
# . - .
# proved - proved
# claimants - claimant
# , - ,
# production - production
# written - written
# contract - contract
# , - ,
# Harrison - Harrison
# , - ,
# twenty-second - twenty-second
# May - May
# , - ,
# 1840 - 1840
# , - ,
# consideration - consideration
# claimants - claimant
# involved - involved
# , - ,
# indorsers - indorser
# Burton - Burton
# & - &
# Harrison - Harrison
# Sumter - Sumter
# county - county
# , - ,
# exposed - exposed
# execution - execution
# , - ,
# amounting - amounting
# upwards - upwards
# fourteen - fourteen
# thousand - thousand
# dollars - dollar
# , - ,
# bargained - bargained
# ...

# %%
#panda library
import pandas as pd
d1 = pd.read_fwf('stopwords-removed.txt')
d1.to_csv('stopwords-removed.csv')

# %%
import pandas as pd
d1 = pd.read_csv("stopwords-removed.txt", sep="\n")
d1
# Out:
# Empty DataFrame
# ...

# %%
#Frequency of all terms
import re
import string
freq = {}
document_text = open('stopwords-removed.txt', 'r')
text_string = document_text.read().lower()
match_pattern = re.findall(r'\b[a-z]{3,15}\b', text_string)

for word in match_pattern:
    count = freq.get(word,0)
    freq[word] = count + 1
    
listnew = freq.keys()

for wordd in listnew:
    print(wordd, freq[wordd])
# Out:
# ala 60
# supreme 4
# court 80
# alabama 4
# adams 4
# tanner 4
# horton 4
# june 4
# term 40
# synopsis 4
# writ 16
# error 24
# circuit 40
# sumter 12
# west 4
# headnotes 4
# chattel 12
# mortgages 4
# crops 12
# growing 64
# crop 196
# existence 8
# subject 36
# matter 16
# mortgage 24
# contract 64
# passes 4
# interest 20
# vest 8
# possession 52
# either 8
# immediately 8
# future 12
# time 48
# cases 12
# cite 8
# headnote 12
# creditors 12
# remedies 4
# lien 100
# priority 4
# prohibiting 8
# levy 100
# gathered 76
# attaches 16
# favor 12
# attach 8
# trial 12
# right 84
# property 40
# statute 36
# november 4
# execution 200
# issued 12
# suit 4
# plaintiff 56
# requiring 8
# sheriff 32
# county 12
# make 8
# goods 4
# allen 12
# harrison 44
# others 4
# sum 4
# thirty 8
# seven 8
# hundred 8
# seventy 4
# dollars 12
# besides 4
# costs 4
# levied 32
# bales 8
# cotton 56
# claimed 8
# bond 4
# given 8
# try 8
# issue 12
# made 32
# question 20
# liability 12
# ...

# %% [markdown]
# Question 3(30 points). Write a python program to conduct **syntax and structure analysis** of the clean text you just sanewfileed abonewfilee. The syntax and structure analysis includes:
#
# (1) Parts of Speech (POS) pos_tag_sentsging: pos_tag_sents Parts of Speech of each word in the text, and calculate the total number of N(oun), newfile(erb), Adj(ectinewfilee), Adnewfile(erb), respectinewfileely.
#
# (2) Constituency Parsing and Dependency Parsing: print out the constituency parsing trees and dependency parsing trees of all the sentences. Using one sentence as an example to explain your understanding about the constituency parsing tree and dependency parsing tree.
#
# (3) Named Entity Recognition: Extract all the entities such as person names, organizations, locations, product names, and date from the clean texts, calculate the count of each entity.

# %%
#POS
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
from nltk import word_tokenize, pos_tag, pos_tag_sents
text = open("stopwords-removed.txt", "r")
text = text.read()
tagged = pos_tag_sents(map(word_tokenize, text))
print(tagged)

nouns=0
verbs=0
adjectives=0
adverbs=0

for i in tagged:
    for j in i:
        if 'NN' in j:
            nouns=nouns+1
        if 'VB' in j:
            verbs+=1
        if 'ADJ' in j:
            adjectives+=1
        if 'ADV' in j:
            adverbs+=1
        
print('nouns:', nouns)
print('verbs:', verbs)
print('adjectives:', adjectives)
print('adverbs:', adverbs)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# ...

# %%
#Parsing and Dependency Parsing
import spacy
nlp=spacy.load('en_core_web_sm')
text = open("stopwords-removed.txt", "r")
text = text.read()
for t in nlp(text):
 print(t.text,'=>',t.dep_,'=>',t.head.text)
# Out:
# Streaming output truncated to the last 5000 lines.
# & => cc => Burton
# Harrison => compound => Sumter
# Sumter => compound => county
# county => conj => Burton
# , => punct => Burton
# exposed => amod => execution
# execution => appos => Burton
# , => punct => indorsers
# amounting => advcl => indorsers
# upwards => advmod => amounting
# fourteen => compound => thousand
# thousand => nummod => dollars
# dollars => dobj => amounting
# , => punct => indorsers
# bargained => conj => indorsers
# sold => dep => indorsers
# claimants => dobj => sold
# growing => acl => claimants
# crop => compound => cotton
# cotton => dobj => growing
# & => cc => cotton
# c. => conj => cotton
# , => punct => sold
# consisting => advcl => sold
# one => nummod => acres
# hundred => compound => twenty
# twenty => nummod => acres
# acres => dobj => consisting
# , => punct => sold
# & => cc => sold
# c. => compound => Harrison
# Allen => compound => Harrison
# Harrison => nsubj => promised
# ...

# %%
! pip install benepar
# Out:
# ...
#      |████████████████████████████████| 3.3 MB 8.4 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 30.8 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 57.1 MB/s
# ...
#      |████████████████████████████████| 636 kB 65.3 MB/s
# ...
#      |████████████████████████████████| 52 kB 1.7 MB/s
# ...
#      |████████████████████████████████| 895 kB 61.4 MB/s
# ...
#   Created wheel for benepar: filename=benepar-0.2.0-py3-none-any.whl size=37647 sha256=a3dbe06a9c3fe0d24c5ca72f175337742e5804971158653d25d72804fdf2db8c
#   Stored in directory: /root/.cache/pip/wheels/dc/6f/a3/4d27ce92766bdedd2cbbbedb8857fb7a53534331191cda4994
# Successfully built benepar
# ...
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# ...

# %%
# !python -m spacy download en_core_web_md
# Out:
# ...
#      |████████████████████████████████| 96.4 MB 1.1 MB/s
# ...
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')

# %%
import benepar
benepar.download('benepar_en3')
# Out:
# [nltk_data] Downloading package benepar_en3 to /root/nltk_data...
# [nltk_data]   Package benepar_en3 is already up-to-date!
# True

# %%
from benepar.spacy_plugin import BeneparComponent

nlp = spacy.load('en')
nlp.add_pipe(BeneparComponent('benepar_en3'))

t = open("stopwo-remonewfileed.txt", "r")
t = t.read()

for i in range(0,99):
  list (nlp(text).sents)[0]._.parse_string
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-106-73e3218ed054> in <module>()
# ----> 1 from benepar.spacy_plugin import BeneparComponent
#       2
#       3 nlp = spacy.load('en')
#       4 nlp.add_pipe(BeneparComponent('benepar_en3'))
#       5
#
# ModuleNotFoundError: No module named 'benepar'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
#Named Entity Recognition
import spacy
  
nlp = spacy.load('en_core_web_sm')
  
text = open("stopwords-removed.txt", "r")
text = text.read()
  
doc1 = nlp(text)
  
for ent12 in doc1.ents:
    print(ent12.text, ent12.start_char, ent12.end_char, ent12.label_)
# Out:
# Ala. 740 3 11 ORG
# Supreme Court 12 25 ORG
# Alabama 26 33 PERSON
# June Term, 1843 59 74 DATE
# Synopsis WRIT Error Circuit Court 76 109 ORG
# West Headnotes 118 132 GPE
# 2 134 135 CARDINAL
# 1 138 139 CARDINAL
# 4 286 287 CARDINAL
# 2 309 310 CARDINAL
# lien 387 391 PERSON
# lien attach 429 440 PERSON
# 5 456 457 CARDINAL
# 1 480 481 CARDINAL
# November, 1840 512 526 DATE
# Allen Harrison 632 646 PERSON
# thirty-seven hundred 659 679 QUANTITY
# seventy-seven 680 693 CARDINAL
# thirty bales 742 754 QUANTITY
# Allen Harrison 772 786 PERSON
# October, 1839 985 998 DATE
# 741 1011 1014 CARDINAL
# thereon 7th Nov. 1022 1038 ORG
# alias pluries fieri facias’ 1051 1078 ORG
# Harrison 1145 1153 ORG
# Harrison 1228 1236 ORG
# twenty-second May, 1840 1238 1261 DATE
# Burton & Harrison 1307 1324 ORG
# fourteen thousand dollars 1377 1402 MONEY
# one hundred twenty acres 1465 1489 QUANTITY
# Allen Harrison 1495 1509 PERSON
# Gainesville 1629 1640 PERSON
# Tennessee 1657 1666 GPE
# ...

# %% [markdown]
# **Write your explanations of the constituency parsing tree and dependency parsing tree here (Question 3-2):**

# %%
# You explaination here
I used the Spacy package to parse the text and analyze the sentence in dependency parsing.
I used the for loop to cycle through all of the text data in the file and analyze all of the sentences.
Constituency parsing is the process of breaking down sentences further to study the grammar, such as sub-sentences.

# %% [markdown]
# # **Question 4**

# %% [markdown]
# (20 points) Python Regular Expression.
#
# (1) Write a Python program to remonewfilee leading zeros from an IP link.
#
# ip = "260.08.094.109"
#
#
# (2) Write a Python Program to extract all the years from the following sentence.
#
# sentence = "The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies hanewfilee happened. As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019. The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys' soccer team from a flooded canewfilee to the dinewfileisinewfilee election of President Donald Trump."

# %%
import re

ip_link = input("enter ip link:")
link = ip_link.split(".")
link = [int(part) for part in link]
link = [str(part) for part in link]
ip_link = ".".join(link) 
print("After remonewfileing leading zeros:", ip_link)

s = '''The 2010s were a dramatic decade, filled with ups and downs, more than 1000 stroies hanewfilee happened.
    As the decade comes to a close, Insider took a look back at some of the biggest headline-grabbing stories, from 2010 to 2019.
    The result was 119 news stories that ranged from the heartwarming rescue of a Thai boys soccer team from a flooded
    canewfilee to the dinewfileisinewfilee election of President Donald Trump'''

output = re.findall(r"(2+\d{3})", s)
print("Years:", output)
# Out:
# enter ip link:260.08.094.109
# After remonewfileing leading zeros: 260.8.94.109
# Years: ['2010', '2010', '2019']
